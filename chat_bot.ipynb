# %%
#This is the motivater app that gives a quotes a day
#by Steven Garner #date: 9/7/2020 version 1

import random

q_maker = random.randint(1,7) # genurate a number for the next quote

quote_number = q_maker
print(q_maker)
dict_quote = {
  "q1": "The days",
  "q2": "The week",
  "q3": 1964,
  "q4": "asif",
  "q5": "The hill",
  "q6": 101010,
   "q7": "Steven King",
    
}

if quote_number ==  1:
    print(dict_quote.get("q1"))
elif  quote_number ==  2:
    print(dict_quote.get("q2"))
elif  quote_number ==  3:
    print(dict_quote.get("q3"))
elif  quote_number ==  4:
    print(dict_quote.get("q4"))
elif  quote_number ==  5:
    print(dict_quote.get("q6"))
elif  quote_number ==  6:
    print(dict_quote.get("q7"))
elif  quote_number ==  7:
    print(dict_quote.get("q7"))
# Out:
# 5
# 101010

# %%
import random

q_maker = random.randint(1,7) # genurate a number for the next quote

quote_dice = q_maker
sport_dice = random.randint(1,7)

print(q_maker)

print("Your roled once dice one " + str(quote_dice) + " and the second dice" +  str(sport_dice))

dict_quote = {
  "q1": "The days",
  "q2": "The week",
  "q3": 1964,
  "q4": "asif",
  "q5": "The hill",
  "q6": 101010,
  "q7": "Steven King",
    
}

dict_sport={
  "q1": "Sports day",
  "q2": "The cat sat on the mate",
  "q3": 1964,
  "q4": "to be or not to be",
  "q5": "The hill",
  "q6": 101010,
  "q7": "Steven King",    
    
}
"""
this is the first quote block out of three if dice one roles 1-6 a quote will be printed out if the arument is 
then it will go to the next function

"""
    


def first_quote():
    if quote_dice ==  1:
        print(dict_quote.get("q1"))
    elif  quote_dice ==  2:
        print(dict_quote.get("q2"))
    elif  quote_dice ==  3:
        print(dict_quote.get("q3"))
    elif  quote_dice ==  4:
        print(dict_quote.get("q4"))
    elif  quote_dice ==  5:
        print(dict_quote.get("q6"))
    elif  quote_dice ==  6:
        print(dict_quote.get("q7"))
    elif  quote_dice ==  7:
        print(dict_quote.get("q7"))
first_quote()

def sec_quote():
    if sport_dice ==  1:
        print(dict_sport.get("q1"))
    elif  sport_dice ==  2:
        print(dict_sport.get("q2"))
    elif  sport_dice ==  3:
        print(dict_sport.get("q3"))
    elif  sport_dice ==  4: 
        print(dict_sport.get("q4"))
    elif  sport_dice ==  5:
        print(dict_sport.get("q6"))
    elif  sport_dice ==  6:
        print(dict_sport.get("q7"))
    elif  sport_dice ==  7:
        print(dict_sport.get("q8"))
sec_quote()
# Out:
# 6
# Your roled once dice one 6 and the second dice6
# Steven King
# Steven King

# %%
"""
Check for doubles if a doubles happen it print for the doubles dictary

"""
import random
q_maker = random.randint(1,2) # genurate a number for the next quote

quote_dice = q_maker
sport_dice = random.randint(1,1)
check_double_dice = sport_dice and quote_dice
# print(q_maker)
print(check_double_dice, "You have rolled a double")
print("Your roled on dice one " + str(quote_dice) + " and the second dice " +  str(sport_dice))

dict_quote = {
  "q1": "The days",
  "q2": "The week",
  "q3": 1964,
  "q4": "asif",
  "q5": "The hill",
  "q6": 101010,
  "q7": "Steven King",
    
}

dict_sport={
  "q1": "Sports day",
  "q2": "The cat sat on the mate",
  "q3": 1964,
  "q4": "to be or not to be",
  "q5": "The hill",
  "q6": 101010,
  "q7": "Steven King",    
    
}
dict_double={
  "q1": "Bingo",
  "q2": "Two of a kind",
  "q3":  "Two == double",
  "q4": "The double value",
  "q5": "T",
  "q6": 1,    
}




"""
this is the first quote block out of three if dice one roles 1-6 a quote will be printed out if the arument is 
then it will go to the next function

"""
def chk_doubles():
    if quote_dice == sport_dice:
        print("You have roled a double")
        
    else:
        print("You have not roled a double")
chk_doubles()


def first_quote():
    if quote_dice ==  1:
        print(dict_quote.get("q1"))
    elif  quote_dice ==  2:
        print(dict_quote.get("q2"))
    elif  quote_dice ==  3:
        print(dict_quote.get("q3"))
    elif  quote_dice ==  4:
        print(dict_quote.get("q4"))
    elif  quote_dice ==  5:
        print(dict_quote.get("q6"))
    elif  quote_dice ==  6:
        print(dict_quote.get("q7"))
    elif  quote_dice ==  7:
        print(dict_quote.get("q7"))
first_quote()

def sec_quote():
    if sport_dice ==  1:
        print(dict_sport.get("q1"))
    elif  sport_dice ==  2:
        print(dict_sport.get("q2"))
    elif  sport_dice ==  3:
        print(dict_sport.get("q3"))
    elif  sport_dice ==  4:
        print(dict_sport.get("q4"))
    elif  sport_dice ==  5:
        print(dict_sport.get("q6"))
    elif  sport_dice ==  6:
        print(dict_sport.get("q7"))
    elif  sport_dice ==  7:
        print(dict_sport.get("q8"))
sec_quote()
# Out:
# 1 You have rolled a double
# Your roled on dice one 1 and the second dice 1
# You have roled a double
# The days
# Sports day
